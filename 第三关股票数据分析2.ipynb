# %%
import pandas as pd #导入数据分析包
from pandas_datareader import data #pandas_datareader包中可以查询雅虎的股票数据接口。
jfDict={'百度':'BIDU','IBM':'IBM','Facebook':'FB',
            '苹果':'AAPL','阿里巴巴':'BABA','中科曙光':'603019.ss'}

# %% [markdown]
# ## 阿里巴巴

# %%
start_date = '2017-01-01'
end_date = '2018-01-01'#获取数据的时间范围
babaDf=data.get_data_yahoo('BABA',start_date, end_date) #get_data_yahoo表示从雅虎数据源获取股票数据
#雅虎股票数据源文档：http://pandas-datareader.readthedocs.io/en/latest/remote_data.html#yahoo-finance

# %%
babaDf.head()#查看前5行数据
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-01-03  89.000000  89.000000  88.080002  88.599998  88.599998   8789400
# 2017-01-04  88.985001  90.889999  88.580002  90.510002  90.510002  11490200
# 2017-01-05  91.910004  94.809998  91.639999  94.370003  94.370003  16821500
# 2017-01-06  94.400002  94.500000  93.000000  93.889999  93.889999   7639800
# 2017-01-09  94.160004  95.650002  93.309998  94.720001  94.720001  10792900

# %%
babaDf.describe()#查看数据集描述统计信息
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   141.909542  143.203490  140.260857  141.791793  141.791793
# std     32.090767   32.339500   31.505186   31.875025   31.875025
# min     88.985001   89.000000   88.080002   88.599998   88.599998
# 25%    108.430001  109.124500  107.489998  108.169998  108.169998
# 50%    143.000000  144.380005  141.479996  143.009995  143.009995
# 75%    173.595001  175.139999  171.584999  173.250000  173.250000
# max    191.539993  191.750000  189.369995  191.190002  191.190002
#
#              Volume
# count  2.510000e+02
# mean   1.550723e+07
# std    9.377487e+06
# min    4.120700e+06
# 25%    9.129950e+06
# 50%    1.341080e+07
# 75%    1.864455e+07
# max    8.093690e+07

# %%
def chan(column):
    buyPrice=column[0]
    curPrice=column[4]
    chanPrice=(curPrice-buyPrice)/buyPrice#自定义函数
    if(chanPrice>0):
        print('股票上涨： ',chanPrice)
    elif(chanPrice<0):
        print('股票下跌： ',chanPrice)
    else:#不用跟条件
        print('股票无变化')#if:elif:else:
    return chanPrice#自定义函数最后返回数据

# %%
closeCol3=babaDf['Close']#获取百度close列数据
babachange=chan(closeCol3)#获取Close这一列的数据,运用自定义函数
# Out:
# 股票上涨：  0.0690745275186

# %%
import matplotlib.pyplot as plt#导入绘图包
plt.plot(babaDf['Close'],color='green')#使用Close这一列数据绘制,线的颜色绿色
plt.title('BABA')#标题
plt.xlabel('Date')
plt.ylabel('Closing price')
plt.grid(True)#显示网格
plt.show()#显示图片    生成图片的日期格式

# %% [markdown]
# ## 苹果

# %%
applDf=data.get_data_yahoo(jfDict['苹果'],start_date, end_date)

# %%
applDf.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  115.800003  116.330002  114.760002  116.150002  114.311760
# 2017-01-04  115.849998  116.510002  115.750000  116.019997  114.183815
# 2017-01-05  115.919998  116.860001  115.809998  116.610001  114.764473
# 2017-01-06  116.779999  118.160004  116.470001  117.910004  116.043915
# 2017-01-09  117.949997  119.430000  117.940002  118.989998  117.106812
#
#               Volume
# Date
# 2017-01-03  28781900
# 2017-01-04  21118100
# 2017-01-05  22193600
# 2017-01-06  31751900
# 2017-01-09  33561900

# %%
applDf.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   150.444900  151.406056  149.487650  150.551075  149.510449
# std     14.744788   14.822607   14.479401   14.621191   15.172933
# min    115.800003  116.330002  114.760002  116.019997  114.183815
# 25%    141.895005  142.739998  141.029999  141.815002  140.175697
# 50%    152.449997  153.860001  151.130005  152.740005  151.399048
# 75%    159.714996  160.710007  158.540001  159.855004  159.242546
# max    175.110001  177.199997  174.860001  176.419998  176.419998
#
#              Volume
# count  2.510000e+02
# mean   2.713162e+07
# std    1.128930e+07
# min    1.402670e+07
# 25%    2.041325e+07
# 50%    2.440950e+07
# 75%    2.994720e+07
# max    1.119850e+08

# %%
closeCol4=applDf['Close']
applchange=chan(closeCol4)
import matplotlib.pyplot as plt
plt.plot(applDf['Close'])
plt.title('APPL')
plt.grid(True)
plt.show()
# Out:
# 股票上涨：  0.024451105907
